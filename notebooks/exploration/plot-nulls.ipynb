# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import numpy as np

# %%
in_path='\n'
data=pd.read_csv('D:/programming-no-gdrive/air-pollution/data-intermediate/mpi/Transformed_Data_2000.csv')
data=data.replace(r'\\s+ ', np.nan, regex=True)
nulls=data[data.isnull().any(axis=1)]

# %%
nulls
# Out:
#         Unnamed: 0     AQS_Code      epoch        no       no2       nox  \
# 1               27  48_201_0671  975385500       NaN       NaN       NaN
# 2               36  48_201_0051  957873600       NaN       NaN       NaN
# 3               54  48_201_6000  971344200       NaN       NaN       NaN
# 4               56  48_201_0669  948493200       NaN       NaN       NaN
# 5               65  48_201_0057  977742900       NaN       NaN       NaN
# 6               78  48_201_0551  957534600       NaN       NaN       NaN
# 8              153  48_201_0671  972131100       NaN       NaN       NaN
# 9              159  48_201_0307  960665400       NaN       NaN       NaN
# 11             171  48_201_1049  955723200       NaN       NaN       NaN
# 13             200  48_201_0057  974523300       NaN       NaN       NaN
# 15             208  48_201_0057  966531600       NaN       NaN       NaN
# 17             344  48_201_0671  970583100       NaN       NaN       NaN
# ...

# %%
nulls['AQS_Code'].value_counts()
# Out:
# 48_201_0671    10533
# 48_201_0069     5386
# 48_201_0051     5375
# 48_201_0307     5375
# 48_201_0670     5301
# 48_201_0551     5301
# 48_201_0572     5291
# 48_201_0695     5289
# 48_201_0669     5288
# 48_201_6000     5280
# 48_201_0558     5247
# 48_201_0057     5236
# 48_201_1049     5178
# 48_201_0673     5172
# 48_201_0803      932
# 48_201_0024      591
# 48_201_1034      446
# 48_201_1035      422
# Name: AQS_Code, dtype: int64

# %%
from matplotlib import cm
a=np.random.random(40)
cs=cm.Set3(np.arange(40)/40.)

# %%
plt.pie(list(nulls['AQS_Code'].value_counts()), labels=nulls['AQS_Code'].unique(), colors=cm)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-56-4ba316588e84> in <module>
# ----> 1 plt.pie(list(nulls['AQS_Code'].value_counts()), labels=nulls['AQS_Code'].unique(), colors=cm)
#
# ~\Anaconda3\envs\deep-learning\lib\site-packages\matplotlib\pyplot.py in pie(x, explode, labels, colors, autopct, pctdistance, shadow, labeldistance, startangle, radius, counterclock, wedgeprops, textprops, center, frame, rotatelabels, data)
#    2803         wedgeprops=wedgeprops, textprops=textprops, center=center,
#    2804         frame=frame, rotatelabels=rotatelabels, **({"data": data} if
# -> 2805         data is not None else {}))
#    2806
#    2807
#
# ~\Anaconda3\envs\deep-learning\lib\site-packages\matplotlib\__init__.py in inner(ax, data, *args, **kwargs)
#    1808                         "the Matplotlib list!)" % (label_namer, func.__name__),
# ...
