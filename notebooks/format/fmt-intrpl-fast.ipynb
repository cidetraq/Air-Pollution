# %%
import pandas as pd
import numpy as np
from sklearn.model_selection import train_test_split

# %%
data=pd.read_csv("D:/programming-no-gdrive/air-pollution/data-formatted/ready/Data_2000_ready.csv")

# %%
data=data.drop(['temp_flag'], axis=1)

# %%
orig=data

# %%
len(orig)/len(data)
# Out:
# 14.81177

# %%
#for testing
data=orig[0:100000]

# %%
import collections
Row = collections.namedtuple('day', 'hour')
prev_row = Row(hour=0)

# %%
Row = collections.namedtuple('day', 'hour')

# %%
all_days=pd.DataFrame()
count=0
for day in range(1,32):
    day_df=data[data['day']==day]
    index=0
    prev_row=Row(hour=0)
    days=pd.DataFrame()
    for tup in day_df.itertuples():
        if tup.hour>=prev_row.hour:
            count+=1
        else:
            newseries=pd.Series(tup)
            newseries=pd.concat([newseries, pd.Series(count).rename({0: 'count'})])
            #print(newseries)
            days=pd.concat([days,newseries], axis=1)
            #print(days)
            count=0
        prev_row=tup
    all_days=pd.concat([all_days, days], axis=1)
all_days=all_days.transpose()
all_days=all_days.drop([0], axis=1)
listcol=list(data.columns)
listcol.append('count')
all_days.columns=listcol
all_days
# Out:
# C:\Users\nicholas\Anaconda3\envs\deep-learning\lib\site-packages\ipykernel_launcher.py:15: FutureWarning: Sorting because non-concatenation axis is not aligned. A future version
# of pandas will change to not sort by default.
#
# To accept the future behavior, pass 'sort=False'.
#
# To retain the current behavior and silence the warning, pass 'sort=True'.
#
#   from ipykernel import kernelapp as app
#        AQS_Code Latitude Longitude      epoch       no      no2      nox  \
# 0   48_201_1034   29.768  -95.2206  951868800  0.79971  3.92394   4.6023
# 0   48_201_1034   29.768  -95.2206  954547200  1.97427   24.722   26.013
# 0   48_201_1034   29.768  -95.2206  957139200   0.1218  8.49854  8.45055
# 0   48_201_1034   29.768  -95.2206  959817600  1.48594  16.0987  18.2367
# 0   48_201_1034   29.768  -95.2206  962409600  0.89193  5.18441  6.21287
# 0   48_201_1034   29.768  -95.2206  965088300  35.4703  43.9057  79.1409
# ...

# %%
orig.iloc[0]['epoch']
# Out:
# 949363200

# %%
all_days
# Out:
#        AQS_Code Latitude Longitude      epoch       no      no2      nox  \
# 0   48_201_1034   29.768  -95.2206  951868800  0.79971  3.92394   4.6023
# 0   48_201_1034   29.768  -95.2206  954547200  1.97427   24.722   26.013
# 0   48_201_1034   29.768  -95.2206  957139200   0.1218  8.49854  8.45055
# 0   48_201_1034   29.768  -95.2206  959817600  1.48594  16.0987  18.2367
# 0   48_201_1034   29.768  -95.2206  962409600  0.89193  5.18441  6.21287
# 0   48_201_1034   29.768  -95.2206  965088300  35.4703  43.9057  79.1409
# 0   48_201_1034   29.768  -95.2206  967766400 -0.05006  17.1574  17.3833
# 0   48_201_1034   29.768  -95.2206  970358400        0  23.0206   23.772
# 0   48_201_1034   29.768  -95.2206  973036800  0.20026  10.6647  11.7622
# 0   48_201_1034   29.768  -95.2206  975628800  9.83755  32.8336  41.6752
# 0   48_201_1034   29.768  -95.2206  978307200  8.65759  20.8717  30.1803
# 0   48_141_0027  31.7631  -106.487  949363200  20.1908  26.6137  46.4562
# ...

# %%
all_days['count'].unique()
# Out:
# array([288, 264, 287, 245, 250, 286, 261, 528, 499, 184, 575, 285, 263,
#        247, 529, 500, 215, 248, 246, 348, 515, 202, 210, 538, 222, 552,
#        194, 179, 510, 537, 249, 237, 238, 310, 295, 162, 477, 260, 284,
#        220, 540, 119, 274, 258, 517, 536, 228, 262, 165], dtype=object)

# %%
ground_truth=all_days[all_days['count']>=287]

# %%
ground_truth['count'].value_counts()
# Out:
# 287    116
# 575      7
# 515      4
# 552      4
# 540      2
# 538      2
# 529      1
# 517      1
# 295      1
# 528      1
# 500      1
# 499      1
# 510      1
# 310      1
# 536      1
# 537      1
# 348      1
# 477      1
# 288      1
# Name: count, dtype: int64

# %%
ground_truth
# Out:
#       AQS_Code Latitude Longitude      epoch       no      no2      nox  \
# 0  48_201_1034   29.768  -95.2206  951868800  0.79971  3.92394   4.6023
# 0  48_201_1034   29.768  -95.2206  951955200  0.99963   7.5846   8.2041
# 0  48_201_1034   29.768  -95.2206  952041600  0.89967  5.01461   5.6028
# 0  48_201_1034   29.768  -95.2206  952128000  9.19662  29.5361   38.119
# 0  48_201_1034   29.768  -95.2206  952214400  6.29769  31.1408  37.0185
# 0  48_201_1034   29.768  -95.2206  952300800  0.09996  9.32718  9.30465
# 0  48_201_1034   29.768  -95.2206  952387200  1.54943  22.7413  24.1621
# 0  48_201_1034   29.768  -95.2206  952473600   3.5487  18.3786  21.7609
# 0  48_201_1034   29.768  -95.2206  952560000  1.74936   6.7948  7.95397
# 0  48_201_1034   29.768  -95.2206  952646400  1.49945  9.01377  10.2051
# 0  48_201_1034   29.768  -95.2206  952732800   1.0996  8.51231   9.6048
# 0  48_201_1034   29.768  -95.2206  952819200  8.09702  15.2319  23.3117
# ...

# %%
ground_truth_keys=ground_truth

# %%
ground_truth=pd.DataFrame()
#count=0
valid_epochs
for tup in day_df.itertuples():
    if tup.hour>=prev_row.hour:
        count+=1
    else:
        newseries=pd.Series(tup)
        newseries=pd.concat([newseries, pd.Series(count).rename({0: 'count'})])
        #print(newseries)
        days=pd.concat([days,newseries], axis=1)
        #print(days)
        count=0
        prev_row=tup
    all_days=pd.concat([all_days, days], axis=1)
all_days=all_days.transpose()
all_days=all_days.drop([0], axis=1)
listcol=list(data.columns)
listcol.append('count')
all_days.columns=listcol
all_days
